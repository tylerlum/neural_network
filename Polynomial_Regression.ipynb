# %% [markdown]
# <a href="https://colab.research.google.com/github/tylerlum/neural_network/blob/master/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)

## Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
## Make sine curve with variance
points = 500
X = np.linspace(-3, 3, points)
Y = np.sin(X) + np.random.uniform(-0.5,0.5, points)

plt.scatter(X, Y)
plt.show()

# %%
## Create Sequential model
model = Sequential()
model.add(Dense(50, activation='sigmoid', input_dim=1))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))

# %%
## Create optimizer and train model
adam = Adam(lr=0.01)
model.compile(loss='mse', optimizer=adam)
model.fit(X, Y, epochs=50)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4536
# Epoch 2/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.2398
# Epoch 3/50
# 500/500 [==============================] - 0s 50us/step - loss: 0.2612
# Epoch 4/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.2255
# Epoch 5/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.2281
# Epoch 6/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.2249
# Epoch 7/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.2175
# Epoch 8/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.2198
# Epoch 9/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.2041
# Epoch 10/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.1903
# Epoch 11/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.1900
# Epoch 12/50
# ...

# %%
## Plot model
predictions = model.predict(X)
plt.scatter(X, Y)
plt.plot(X, predictions, 'ro')
plt.show()
